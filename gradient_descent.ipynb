# %% [markdown]
# <a href="https://colab.research.google.com/github/rupali-01/gradientdescent/blob/main/gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf6344f3-7bdf-4a37-9327-e2f0939d7814" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf6344f3-7bdf-4a37-9327-e2f0939d7814">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(list(uploaded.keys())[0])

# %%
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age','affordibility']],df.bought_insurance,train_size=0.8)

# %%
X_train
# Out:
#     age  affordibility
# 26   23              1
# 9    61              1
# 4    46              1
# 22   40              1
# 5    56              1
# 27   46              1
# 10   18              1
# 7    60              0
# 12   27              0
# 11   28              1
# 24   50              1
# 18   19              0
# 1    25              0
# 0    22              1
# 21   26              0
# 20   21              1
# 17   58              1
# 2    47              1
# 3    52              0
# 23   45              1
# 6    55              0
# 15   55              1

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age'] / 100

X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age'] / 100

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_scaled, y_train, epochs=500)
# Out:
# Epoch 1/500
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step - accuracy: 0.4545 - loss: 0.7544
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4545 - loss: 0.7539
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4545 - loss: 0.7534
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4545 - loss: 0.7529
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4545 - loss: 0.7524
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4545 - loss: 0.7520
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4545 - loss: 0.7515
# Epoch 8/500
# ...

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6667 - loss: 0.5980
# [0.5979940295219421, 0.6666666865348816]

# %%
model.predict(X_test_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# array([[0.65140706],
#        [0.5918772 ],
#        [0.44112504],
#        [0.6640873 ],
#        [0.6433701 ],
#        [0.4480801 ]], dtype=float32)

# %%
coef, intercept = model.get_weights()

# %%
coef, intercept
# Out:
# (array([[0.7041618],
#         [0.6576201]], dtype=float32),
#  array([-0.41263783], dtype=float32))

# %% [markdown]
# FUNCTION DEFINED:

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
def upload_file():
  from google.colab import files
  uploaded = files.upload()
  df = pd.read_csv(list(uploaded.keys())[0])
  print("Uploaded dataset columns:", df.columns)
  return df

# %%
def preprocess_data(df):
    x = df[['age', 'affordibility']]
    y = df['bought_insurance']
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8)
    x_train_scaled = x_train.copy()
    x_test_scaled = x_test.copy()
    x_train_scaled['age'] = x_train_scaled['age'] / 100
    x_test_scaled['age'] = x_test_scaled['age'] / 100
    return x_train_scaled, x_test_scaled, y_train, y_test

# %%
def create_model():
    model = keras.Sequential([
        keras.layers.Dense(1, input_shape=(2,), activation='sigmoid',
                           kernel_initializer='ones', bias_initializer='zeros')
    ])
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
def train_model(model, x_train, y_train):
    model.fit(x_train, y_train, epochs=500)
    return model

# %%
def evaluate_model(model, x_test, y_test):
    loss, accuracy = model.evaluate(x_test, y_test)
    return loss, accuracy

# %%
def get_model_weights(model):
    coef, intercepts = model.get_weights()
    return coef, intercepts

# %%
def main():
    df = upload_file()
    print(df.head())

    x_train_scaled, x_test_scaled, y_train, y_test = preprocess_data(df)

    model = create_model()
    model = train_model(model, x_train_scaled, y_train)

    loss, accuracy = evaluate_model(model, x_test_scaled, y_test)
    print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

    prediction = model.predict(x_train_scaled)
    coef, intercepts = get_model_weights(model)
    print(f"Model Coefficients: {coef}, Intercepts: {intercepts}")

    return model, prediction

# %%
if __name__ == "__main__":
 main()
# Out:
#      <input type="file" id="files-c4104173-7c42-4618-ae63-80ff45dc09e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4104173-7c42-4618-ae63-80ff45dc09e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
